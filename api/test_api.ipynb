# %%
import os
import re
import json
import requests

if os.path.basename(os.getcwd()) == "api":
    os.chdir("..")
    sys.path.insert(0, os.path.abspath(os.getcwd()))

API_URL = "http://127.0.0.1:8000/optimize"
JSON_PATH = "data/anon_boardHistory_Org9_2023-01-01_2023-01-31.json"

# Carichiamo il Payload
with open(JSON_PATH, 'r') as f:
    hospital_payload = json.load(f)
if isinstance(hospital_payload, dict):
    hospital_payload = [hospital_payload]

res = requests.post(API_URL, json={
    "target_date": "2023-01-04",
    "use_ml": True,
    "payload": hospital_payload
})

if res.status_code == 200:
    assignments = res.json()['raw_assignments']
    display(assignments)
else:
    print("Errore nelle chiamate API. Verifica i log del server.")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Documents/Master Degree/Intelligent System/Automated Planning/Progetto/rehabilitation-scheduling-problem/.venv/lib/python3.13/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/Documents/Master Degree/Intelligent System/Automated Planning/Progetto/rehabilitation-scheduling-problem/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
# ...
